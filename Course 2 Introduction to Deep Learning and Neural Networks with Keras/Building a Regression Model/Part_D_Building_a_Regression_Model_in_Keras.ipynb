# %% [markdown]
# ## Part D: Building a Regression Model in Keras

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import warnings
warnings.simplefilter('ignore', FutureWarning)

import keras

from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical

# %%
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# # Normalize the dataset

# %% [markdown]
# ### Split dataset into predictors and target

# %%
concrete_data_columns = concrete_data.columns

predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# ### Normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# ### Let's save the number of predictors to n_cols since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# ## Training and evaluating the model

# %% [markdown]
# ### Split the dataset into training and testing sets using the normalized dataset above which are predictors_norm for X_train and target for y_train

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(predictors_norm, target, test_size=0.3, random_state=42)

# %%
# define function to train and evaluate the model using mean-squared error
def train_and_evaluate(model, X_train, y_train, X_test, y_test, epochs=50):
  model.fit(X_train, y_train, epochs=epochs, batch_size=32)
  predictions = model.predict(X_test)
  mse = mean_squared_error(y_test, predictions)
  return mse

# Create a list to store mean squared errors
mse_list = []

# Repeat the training and evaluation process 50 times, this time adding 2 new hidden layers of 10 nodes each
for _ in range(50):
  model = Sequential()
  model.add(Dense(10, activation='relu', input_shape=(X_train.shape[1],)))
  model.add(Dense(10, activation= 'relu'))
  model.add(Dense(10, activation= 'relu'))
  model.add(Dense(1))

  model.compile(optimizer='adam', loss='mean_squared_error')


  mse = train_and_evaluate(model, X_train, y_train, X_test, y_test)
  mse_list.append(mse)

# Calculate mean and standard deviation of MSE
mean_mse = np.mean(mse_list)
std_mse = np.std(mse_list)

print("MSE List:",mse_list)
print("Mean MSE:", mean_mse)
print("Standard Deviation of MSE:", std_mse)
# Out:
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1608.4640
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1530.0531
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1473.4325
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1477.5253
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1481.8611
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1403.9517
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1343.7493
# Epoch 8/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1181.2394
# Epoch 9/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 886.4402
# Epoch 10/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 653.7320
# Epoch 11/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 439.8789
# Epoch 12/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 318.5029
# Epoch 13/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 290.7191
# Epoch 14/50
# ...

# %% [markdown]
# ## Comparision

# %% [markdown]
# Comparing the results from Part C with Part B we can see that the mean MSE becomes much lower at 122 compared to Part A's mean MSE being 332. Furthermore we can also see that Part D's standard deviation of MSE is much lower at 14 compared to Part B's at 72. This means that having more hidden layers in the neural network generally produces better results.
